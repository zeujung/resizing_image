# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
Image.MAX_IMAGE_PIXELS = None
img = Image.open('/workspace/ex_hdd/CAMELYON17/lp001_edf.jpg')

# %%
img.size
# Out:
# (65500, 65500)

# %%
img2 = img.resize((img.size[0] // 100, img.size[1] // 100))

# %%
plt.imshow(img2)
